# %% [markdown]
# # 01 — Eksplorasi Data (EDA)
#
# Notebook awal untuk memeriksa dataset kuesioner santriwati sebelum pipeline dijalankan.
#
# Acuan: `SPESIFIKASI-SISTEM-PREDIKSI-HAID.md` §4 (skema data).

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent / "src"))

import pandas as pd
from prediksi_haid import constants

print("Fitur:", constants.FEATURE_COLUMNS)
print("Target:", constants.TARGET_COLUMN)

# %%
# Muat contoh dataset (ganti dengan data asli di data/raw/)
df = pd.read_csv("../data/raw/contoh_kuesioner_santriwati.csv")
df.head()

# %%
df.info()
df["keteraturan_haid"].value_counts()
